# %% [markdown]
# # What's New Section Updater
#
# Written by: Jack A. Cole, Ph.D.
# Mindware Consulting, Inc.
# https://www.linkedin.com/in/jack-cole-b84b5638/
#
#
# This notebook will update the "What's New" field in App Store Connect for the latest release of the app.  This is a strong pain point for apps that have many languages, as the App Store Connect UI does not allow for bulk editing of the "What's New" field.  This notebook will allow you to update the "What's New" field for all languages at once.

# %% [markdown]
# # Instructions
#
# In App Store Connect, go to Users and Access/Integrations.
#
# Create a new API key and download the key file.  You will need the key ID, issuer ID, and the key file.
#
# Create a new app version for your app in App Store Connect.  You will need the app ID and the version ID.
#
# Enter all of the above information in the cell below.
#
# Enter the text for the "What's New" field in the cell below.  This will be automatically translated into all languages for your app.
#
# Run the notebook.

# %%
# !pip install googletrans==4.0.0-rc1
# !pip install Pyjwt

# %%
# Define your credentials
issuer_id = ''
key_id = ''
private_key_file_path = r''
# Define your app's ID and version ID
your_app_id = ""
your_version_id = ""

# Your app's new features in English
new_features_en = "This is a minor update, which includes bug fixes and performance improvements."

# %%
import requests
import json
from googletrans import Translator
import jwt
import time
from pathlib import Path

language_code_mapping = {
    'zh-Hans': 'zh-CN',  # Simplified Chinese
    'zh-Hant': 'zh-TW',  # Traditional Chinese
    'ar-SA': 'ar',       # Arabic (Saudi Arabia)
    'nl-NL': 'nl',       # Dutch (Netherlands)
    'en-US': 'en',       # English (United States)
    'en-GB': 'en',       # English (Great Britain)
    'en-CA': 'en',       # English (Canada)
    'en-AU': 'en',       # English (Australia)
    'fr-CA': 'fr',       # French (Canada)
    'pt-BR': 'pt',       # Portuguese (Brazil)
    'es-MX': 'es',       # Spanish (Mexico)
    'es-ES': 'es',       # Spanish (Spain)
    'pt-PT': 'pt',       # Portuguese
    'de-DE': 'de',       # German
    'fr-FR': 'fr',       # French    
    # Add other mappings as needed
    # For other languages not listed here, you can default to their two-letter ISO 639-1 codes
}

def create_jwt_token(issuer_id, key_id, private_key_file):
    # The token is valid for 20 minutes
    expiration_time = int(time.time()) + (20 * 60)

    # Read the private key
    with Path(private_key_file).open('r') as file:
        private_key = file.read()

    # Payload for the JWT
    payload = {
        'iss': issuer_id,
        'exp': expiration_time,
        'aud': 'appstoreconnect-v1'
    }

    # Header for the JWT
    header = {
        'alg': 'ES256',
        'kid': key_id,
        'typ': 'JWT'
    }

    # Generate the JWT token
    token = jwt.encode(payload, private_key, algorithm='ES256', headers=header)

    return token

# Function to get appStoreVersionId for a specific version
def get_app_store_version_id(app_id, version, auth_token):
    url = f"https://api.appstoreconnect.apple.com/v1/apps/{app_id}/appStoreVersions"
    headers = get_headers(auth_token)
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        versions = response.json()['data']
        for version_info in versions:
            if version_info['attributes']['versionString'] == version:
                return version_info['id']
    else:
        print(f"Failed to retrieve app store versions: {response.text}")
        return None

# Function to get JWT token header
def get_headers(auth_token):
    return {
        'Authorization': f'Bearer {auth_token}',
        'Content-Type': 'application/json'
    }

# Function to list apps
def list_apps(auth_token):
    url = "https://api.appstoreconnect.apple.com/v1/apps"
    headers = get_headers(auth_token)
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        apps = response.json()
        return apps['data']
    else:
        print(f"Failed to list apps: {response.text}")
        return []

# Function to get app_info_id
def get_app_info_id(app_id, auth_token):
    # First, get the related link for appInfos
    url = f"https://api.appstoreconnect.apple.com/v1/apps/{app_id}/relationships/appInfos"
    headers = get_headers(auth_token)
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        related_link = response.json()['links']['related']
        # Then, make a request to the related link to get appInfos
        response = requests.get(related_link, headers=headers)
        if response.status_code == 200:
            app_infos = response.json()['data']
            if app_infos:
                return app_infos[0]['id']  # Assuming you want the first appInfo ID
            else:
                print("No appInfos found for this app.")
                return None
        else:
            print(f"Failed to retrieve app info from related link: {response.text}")
            return None
    else:
        print(f"Failed to retrieve related link for app infos: {response.text}")
        return None

# Function to get supported languages and their localization IDs for a specific app version
def get_supported_languages(app_store_version_id, auth_token):
    url = f"https://api.appstoreconnect.apple.com/v1/appStoreVersions/{app_store_version_id}/appStoreVersionLocalizations"
    headers = get_headers(auth_token)
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        localizations = response.json()['data']
        languages_and_ids = {loc['attributes']['locale']: loc['id'] for loc in localizations}
        return languages_and_ids
    else:
        print(f"Failed to retrieve localizations for app version: {response.text}")
        return {}

def update_whats_new(localization_id, whats_new_text, auth_token):
    url = f"https://api.appstoreconnect.apple.com/v1/appStoreVersionLocalizations/{localization_id}"
    payload = json.dumps({
        'data': {
            'type': 'appStoreVersionLocalizations',
            'id': localization_id,
            'attributes': {
                'whatsNew': whats_new_text
            }
        }
    })
    response = requests.patch(url, headers=get_headers(auth_token=auth_token), data=payload)
    if response.status_code == 200:
        print(f"Successfully updated for localization ID: {localization_id}")
    else:
        print(f"Failed to update for localization ID {localization_id}: {response.text}")

def translate_and_back_translate(text, app_store_language_code):
    # Map App Store language code to Google Translate code
    google_translate_code = language_code_mapping.get(app_store_language_code, app_store_language_code)
    
    try:
        translator = Translator()
        # Translate to the target language
        translated_text = translator.translate(text, dest=google_translate_code).text
        # Back translate to English
        back_translated_text = translator.translate(translated_text, dest='en').text
        return translated_text, back_translated_text
    except Exception as e:
        print(f"Error in translation for {app_store_language_code} ({google_translate_code}): {e}")
        return None, None

# Main execution block
if __name__ == "__main__":

    auth_token = create_jwt_token(issuer_id, key_id, private_key_file_path)

    apps = list_apps(auth_token)
    if apps:
        app_id = apps[0]['id']  # or your specific app ID
        app_store_version_id = get_app_store_version_id(app_id, your_version_id, auth_token)
        if app_store_version_id:
            languages_and_ids = get_supported_languages(app_store_version_id, auth_token)
            for lang, localization_id in languages_and_ids.items():
                translation, back_translation = translate_and_back_translate(new_features_en, lang)
                if translation and back_translation:
                    print(f"Language: {lang}, Translation: {translation}, Back Translation: {back_translation}")
                    update_whats_new(localization_id, translation, auth_token)
                else:
                    print(f"Skipping update for language {lang} due to translation error.")
            print("Supported Languages:", list(languages_and_ids.keys()))
        else:
            print("Failed to find app store version ID.")
    else:
        print("No apps found.")
# Out:
# Language: sv, Translation: Detta är en mindre uppdatering, som inkluderar bugfixar och prestandaförbättringar., Back Translation: This is a minor update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: 830d283d-f0ff-4621-a17d-ea0065f842f7
# Language: it, Translation: Questo è un aggiornamento minore, che include correzioni di bug e miglioramenti delle prestazioni., Back Translation: This is a minor update, which includes bug corrections and performance improvements.
# Successfully updated for localization ID: ac64de4e-6a6a-4cc9-a7b6-65a8ac8a7215
# Language: sk, Translation: Toto je menšia aktualizácia, ktorá obsahuje opravy chýb a vylepšenia výkonu., Back Translation: This is a smaller update that contains mistakes and power improvements.
# Successfully updated for localization ID: bc915ec3-66d5-4e13-808e-a1f6f97495cb
# Language: zh-Hans, Translation: 这是一个较小的更新，其中包括错误修复和性能改进。, Back Translation: This is a smaller update, including error repair and performance improvement.
# Successfully updated for localization ID: 8c4c6d45-6515-49cd-b929-caea1f983f84
# Language: fi, Translation: Tämä on pieni päivitys, joka sisältää virhekorjaukset ja suorituskyvyn parannukset., Back Translation: This is a small update that includes error repairs and performance improvements.
# Successfully updated for localization ID: 80c5bcb6-ee6a-4ea7-8d0c-cbf26bf586d6
# Language: no, Translation: Dette er en mindre oppdatering, som inkluderer feilrettinger og ytelsesforbedringer., Back Translation: This is a minor update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: 9d14e610-4a37-4f5d-94e9-140b62ab8daf
# Language: hu, Translation: Ez egy kisebb frissítés, amely magában foglalja a hibajavításokat és a teljesítményjavításokat., Back Translation: This is a minor update that includes bug fixes and performance repairs.
# Successfully updated for localization ID: 15004355-c07e-44ed-8a2d-b3632d1ecfed
# Language: uk, Translation: Це незначне оновлення, яке включає виправлення помилок та покращення продуктивності., Back Translation: This is a slight update that involves correcting errors and improving performance.
# Successfully updated for localization ID: abe1dd89-d36e-425a-9cba-d9346ec0c671
# Language: ms, Translation: Ini adalah kemas kini kecil, termasuk pembetulan pepijat dan penambahbaikan prestasi., Back Translation: These are small updates, including bug fixes and performance improvements.
# Successfully updated for localization ID: a3225438-f187-4029-8c4e-4943faaa1094
# Language: id, Translation: Ini adalah pembaruan kecil, yang mencakup perbaikan bug dan peningkatan kinerja., Back Translation: This is a small update, which includes bug improvement and performance improvement.
# Successfully updated for localization ID: 6da7e992-6b4b-45b5-b4e3-afd2b1c42273
# Language: ar-SA, Translation: هذا تحديث بسيط ، يتضمن إصلاحات الأخطاء وتحسينات الأداء., Back Translation: This is a simple update, including error repairs and performance improvements.
# Successfully updated for localization ID: 1810d77f-7f9a-4d44-9294-8645f061de9d
# Language: en-US, Translation: This is a minor update, which includes bug fixes and performance improvements., Back Translation: This is a minor update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: 8fb6e267-d2d1-42bb-8e56-a0da68b4a697
# Language: pl, Translation: Jest to niewielka aktualizacja, która obejmuje poprawki błędów i ulepszenia wydajności., Back Translation: This is a small update that includes error corrections and performance improvements.
# Successfully updated for localization ID: 5a2af10a-a1a5-485a-bac3-5e0040bb465a
# Language: el, Translation: Πρόκειται για μια μικρή ενημέρωση, η οποία περιλαμβάνει διορθώσεις σφαλμάτων και βελτιώσεις απόδοσης., Back Translation: This is a small update, which includes error corrections and performance improvements.
# Successfully updated for localization ID: ac61c562-c6c1-425a-bc9b-24be15204cd6
# Language: nl-NL, Translation: Dit is een kleine update, die bugfixes en prestatieverbeteringen omvat., Back Translation: This is a small update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: e10f4f75-c752-447a-82dc-9c4f5dcc7102
# Language: vi, Translation: Đây là một bản cập nhật nhỏ, bao gồm các sửa lỗi và cải thiện hiệu suất., Back Translation: This is a small update, including corrections and improving performance.
# Successfully updated for localization ID: 1f958767-527c-4f1f-a266-259c4667a969
# Language: en-GB, Translation: This is a minor update, which includes bug fixes and performance improvements., Back Translation: This is a minor update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: 7f0d43e0-28c9-40ff-b0b2-be96a85a7815
# Language: en-CA, Translation: This is a minor update, which includes bug fixes and performance improvements., Back Translation: This is a minor update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: 8053dba1-b36e-4707-97b2-d25a8cdeaf82
# Language: ja, Translation: これはマイナーなアップデートで、バグの修正とパフォーマンスの改善が含まれます。, Back Translation: This is a minor update that includes bug correction and performance improvement.
# Successfully updated for localization ID: f581e53c-9170-456a-95d6-f577c0a10419
# Language: tr, Translation: Bu, hata düzeltmeleri ve performans iyileştirmeleri içeren küçük bir güncellemedir., Back Translation: This is a small update with bug fixes and performance improvements.
# Successfully updated for localization ID: cc8f6edc-5886-4e2d-920d-ef8317282907
# Language: he, Translation: זהו עדכון מינורי, הכולל תיקוני באגים ושיפורי ביצועים., Back Translation: This is a minor update, which includes bug repairs and performance.
# Successfully updated for localization ID: 6a478e4d-54f9-4d5e-9369-3b174441811e
# Language: fr-CA, Translation: Il s'agit d'une mise à jour mineure, qui comprend des corrections de bogues et des améliorations des performances., Back Translation: This is a minor update, which includes bug corrections and performance improvements.
# Successfully updated for localization ID: 56880b84-9d1b-4ba4-82a3-ba89f9551194
# Language: ca, Translation: Es tracta d’una actualització menor, que inclou solucions d’errors i millores de rendiment., Back Translation: This is a minor update, which includes errors and performance improvements.
# Successfully updated for localization ID: 5ad25ee8-d17c-497b-82c1-6acfa7269898
# Language: ru, Translation: Это незначительное обновление, которое включает в себя исправления ошибок и улучшения производительности., Back Translation: This is a slight update, which includes error corrections and improving performance.
# Successfully updated for localization ID: 91bd21a1-a136-4bdc-8f69-e445807f3630
# Language: hr, Translation: Ovo je manje ažuriranje, što uključuje ispravke pogrešaka i poboljšanja performansi., Back Translation: This is a less update, which includes the corrections of errors and improvement of performance.
# Successfully updated for localization ID: 9288f14e-3937-4640-ad82-a0bf1af57020
# Language: es-MX, Translation: Esta es una actualización menor, que incluye correcciones de errores y mejoras de rendimiento., Back Translation: This is a minor update, which includes error corrections and performance improvements.
# Successfully updated for localization ID: 67b6341e-13ee-46bb-9c62-3482543e0881
# Language: da, Translation: Dette er en mindre opdatering, der inkluderer fejlrettelser og forbedringer af ydelsen., Back Translation: This is a minor update that includes bug fixes and improvements.
# Successfully updated for localization ID: 3e48fcda-ac14-4bbf-a1c2-86741c33e0f5
# Language: en-AU, Translation: This is a minor update, which includes bug fixes and performance improvements., Back Translation: This is a minor update, which includes bug fixes and performance improvements.
# Successfully updated for localization ID: bba64596-87b9-48af-bfce-bea87c983466
# Language: hi, Translation: यह एक मामूली अपडेट है, जिसमें बग फिक्स और प्रदर्शन में सुधार शामिल हैं।, Back Translation: This is a minor update, including bug fix and improving performance.
# Successfully updated for localization ID: f738ba9e-a90c-4c69-9232-5b6e6fbdef35
# Language: ko, Translation: 버그 수정 및 성능 향상이 포함 된 사소한 업데이트입니다., Back Translation: A minor update that includes bug modifications and performance improvements.
# Successfully updated for localization ID: a61b6dfa-00d2-404e-957e-51bdc12cc46c
# Language: zh-Hant, Translation: 這是一個較小的更新，其中包括錯誤修復和性能改進。, Back Translation: This is a smaller update, including error repair and performance improvement.
# Successfully updated for localization ID: 8f06c036-a1c3-432e-aea2-26248a07c5f8
# Language: pt-PT, Translation: Esta é uma atualização menor, que inclui correções de bugs e melhorias de desempenho., Back Translation: This is a smaller update that includes bug corrections and performance improvements.
# Successfully updated for localization ID: cc1e6af7-e554-49bb-8b95-c01c557d75bd
# Language: th, Translation: นี่คือการอัปเดตเล็กน้อยซึ่งรวมถึงการแก้ไขข้อบกพร่องและการปรับปรุงประสิทธิภาพ, Back Translation: This is a little update, which includes defects and efficiency improvements.
# Successfully updated for localization ID: 52cb980d-196e-4259-b9ea-cc7fb99a34cc
# Language: ro, Translation: Aceasta este o actualizare minoră, care include remedieri de erori și îmbunătățiri ale performanței., Back Translation: This is a minor update, which includes remedies for performance errors and improvements.
# Successfully updated for localization ID: 5ea70249-78ab-49be-a504-e0b263986935
# Language: de-DE, Translation: Dies ist ein kleines Update, das Fehlerbehebungen und Leistungsverbesserungen enthält., Back Translation: This is a small update that contains error deposits and performance improvements.
# Successfully updated for localization ID: 0e2f84ad-3e2a-4314-9dfc-997f49d9c398
# Language: es-ES, Translation: Esta es una actualización menor, que incluye correcciones de errores y mejoras de rendimiento., Back Translation: This is a minor update, which includes error corrections and performance improvements.
# Successfully updated for localization ID: decf7feb-76b7-431c-885f-76201e4e7079
# Language: cs, Translation: Toto je menší aktualizace, která zahrnuje opravy chyb a vylepšení výkonu., Back Translation: This is a smaller update that includes bug fixes and performance improvements.
# Successfully updated for localization ID: e817db73-3fdd-447f-92d5-1ad65367b31c
# Language: fr-FR, Translation: Il s'agit d'une mise à jour mineure, qui comprend des corrections de bogues et des améliorations des performances., Back Translation: This is a minor update, which includes bug corrections and performance improvements.
# Successfully updated for localization ID: 611c6cd0-2335-466d-b979-10c03a96e4f1
# Language: pt-BR, Translation: Esta é uma atualização menor, que inclui correções de bugs e melhorias de desempenho., Back Translation: This is a smaller update that includes bug corrections and performance improvements.
# Successfully updated for localization ID: e9487a59-c3ea-4747-a122-3560f7705d3d
# Supported Languages: ['sv', 'it', 'sk', 'zh-Hans', 'fi', 'no', 'hu', 'uk', 'ms', 'id', 'ar-SA', 'en-US', 'pl', 'el', 'nl-NL', 'vi', 'en-GB', 'en-CA', 'ja', 'tr', 'he', 'fr-CA', 'ca', 'ru', 'hr', 'es-MX', 'da', 'en-AU', 'hi', 'ko', 'zh-Hant', 'pt-PT', 'th', 'ro', 'de-DE', 'es-ES', 'cs', 'fr-FR', 'pt-BR']
